# %% [markdown]
# # Exploration of hormonal receptor genes in Wang et al. developing human neocortex dataset - Metacell calculation by SeaCells (only third trimester)

# %% [markdown]
# [Reference paper](https://doi.org/10.1038/s41586-024-08351-7)

# %% [markdown]
# # 1. Environment

# %% [markdown]
# ## 1.1 Modules

# %%
import os
import sys

import numpy as np
import pandas as pd
import scanpy as sc

import pickle

#Plotting
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

#utils
import ipynbname
from datetime import datetime

# SeaCell
import SEACells

#import custom functions
sys.path.append('../')
import functions as fn
# Out:
# findfont: Font family ['Raleway'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Lato'] not found. Falling back to DejaVu Sans.

# %%
# Some plotting aesthetics
# %matplotlib inline

sns.set_style('ticks')
matplotlib.rcParams['figure.figsize'] = [3.5, 3.5]
matplotlib.rcParams['figure.dpi'] = 100

# %%
print("Scanpy version: ", sc.__version__)
print("Pandas version: ", pd.__version__)
print("SEACell version: ", SEACells.__version__)
# Out:
# Scanpy version:  1.9.3
# Pandas version:  2.0.0
# SEACell version:  0.3.3

# %% [markdown]
# ## 1.2 Settings

# %%
sc.settings.verbosity = 3
sc.settings.set_figure_params(dpi=80)

# %% [markdown]
# ## 1.3 Files and parameters

# %%
input_file = '../../../../DataDir/ExternalData/SingleCellData/Wang_IIITrimester_adataMetacells.h5ad'

# %% [markdown]
# ## 1.4 Start computations

# %%
print(datetime.now())
# Out:
# 2026-03-20 14:00:34.387253

# %% [markdown]
# ----

# %% [markdown]
# # 2. Data Load

# %% [markdown]
# ## 2.1 Read adata metacells file

# %%
adata = sc.read(input_file)
adata
# Out:
# AnnData object with n_obs × n_vars = 305 × 20266
#     obs: 'cell_label', 'cell_label_purity', 'agg_sample_id', 'Aggregated_brain_region', 'Auth_Group'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'Aggregated_brain_region_colors', 'agg_sample_id_colors', 'cell_label_colors', 'hvg', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts', 'lognorm', 'raw'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(adata, color=['cell_label'], s=150)
# Out:
# /usr/local/lib/python3.8/dist-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# # 3. Exploration of hormonal receptor gene signature expression

# %%
signatures = '../../../../DataDir/ExternalData/Receptors/EndocrineKeyGenes.txt'
sig = pd.read_csv(signatures, sep="\t", keep_default_na=False)  
genes = sig["GeneName"].values.tolist()

# %%
fn.CustomUmap(adata, genes, embedding="X_umap", s=150)
# Out:
# Missing: {'DIO3', 'CYP19A1'}

# %%
adata.obs
# Out:
#             cell_label  cell_label_purity     agg_sample_id
# SEACell-188      Oligo           0.944444  NIH-M1154-BA10-2  \
# SEACell-79         InN           0.529412   NIH-4267-BA10-2
# SEACell-121        ExN           0.989950  NIH-M2837-BA10-2
# SEACell-43         ExN           0.994286   NIH-4267-BA10-2
# SEACell-281        ExN           1.000000   NIH-4267-BA10-2
# ...                ...                ...               ...
# SEACell-73         ExN           0.983607     NIH-5900-BA17
# SEACell-137        ExN           0.978261     NIH-5900-BA17
# SEACell-104   IPC-Glia           0.847826  NIH-M1154-BA10-2
# SEACell-76    IPC-Glia           0.920000  NIH-M1154-BA10-2
# SEACell-20   Astrocyte           0.857143  NIH-M1154-BA10-2
#
#             Aggregated_brain_region       Auth_Group
# SEACell-188        PreFrontalCortex  Third_trimester
# SEACell-79         PreFrontalCortex  Third_trimester
# SEACell-121        PreFrontalCortex  Third_trimester
# SEACell-43         PreFrontalCortex  Third_trimester
# SEACell-281        PreFrontalCortex  Third_trimester
# ...                             ...              ...
# SEACell-73             VisualCortex  Third_trimester
# SEACell-137            VisualCortex  Third_trimester
# SEACell-104        PreFrontalCortex  Third_trimester
# SEACell-76         PreFrontalCortex  Third_trimester
# SEACell-20         PreFrontalCortex  Third_trimester
#
# [305 rows x 5 columns]

# %%
outdir = "../../../../FigPaper/"

os.makedirs(outdir, exist_ok=True)

sc.settings.figdir = outdir

gene_dict = sig.groupby("Signature")["GeneName"].apply(list).to_dict()


gene_dict_filtered = {
    sig_name: [g for g in genes if g in adata.var_names]
    for sig_name, genes in gene_dict.items()
}

gene_dict_filtered = {k: v for k, v in gene_dict_filtered.items() if v}

if gene_dict_filtered:
    sc.pl.dotplot(
        adata,
        gene_dict_filtered,
        groupby='cell_label',
        save="dotplot_WangIII.png"
    )
else:
    print("None of the specified genes are found.")
# Out:
# /usr/local/lib/python3.8/dist-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)
# WARNING: saving figure to file ../../../../FigPaper/dotplot_dotplot_WangIII.png

# %% [markdown]
# # 4 Save in other formats

# %%
print(datetime.now())
# Out:
# 2026-03-20 14:00:41.917713

# %%
nb_fname = ipynbname.name()
nb_fname
# Out:
# 'SEACellsWang-GeneExploration_ThirdTrimester'

# %%
# %%bash -s "$nb_fname"
# jupyter nbconvert "$1".ipynb --to="python"
# jupyter nbconvert "$1".ipynb --to="html"
# Out:
# [NbConvertApp] Converting notebook SEACellsWang-GeneExploration_ThirdTrimester.ipynb to python
# [NbConvertApp] Writing 2367 bytes to SEACellsWang-GeneExploration_ThirdTrimester.py
# [NbConvertApp] Converting notebook SEACellsWang-GeneExploration_ThirdTrimester.ipynb to html
# [NbConvertApp] Writing 4073919 bytes to SEACellsWang-GeneExploration_ThirdTrimester.html
