# %% [markdown]
# # Exploration of hormonal receptor genes in Wang et al. developing human neocortex dataset - Metacell calculation by SeaCells (only first trimester)

# %% [markdown]
# [Reference paper](https://doi.org/10.1038/s41586-024-08351-7)

# %% [markdown]
# # 1. Environment

# %% [markdown]
# ## 1.1 Modules

# %%
import os
import sys

import numpy as np
import pandas as pd
import scanpy as sc

import pickle

#Plotting
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

#utils
import ipynbname
from datetime import datetime

# SeaCell
import SEACells

#import custom functions
sys.path.append('../')
import functions as fn
# Out:
# findfont: Font family ['Raleway'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Lato'] not found. Falling back to DejaVu Sans.

# %%
# Some plotting aesthetics
# %matplotlib inline

sns.set_style('ticks')
matplotlib.rcParams['figure.figsize'] = [3.5, 3.5]
matplotlib.rcParams['figure.dpi'] = 100

# %%
print("Scanpy version: ", sc.__version__)
print("Pandas version: ", pd.__version__)
print("SEACell version: ", SEACells.__version__)
# Out:
# Scanpy version:  1.9.3
# Pandas version:  2.0.0
# SEACell version:  0.3.3

# %% [markdown]
# ## 1.2 Settings

# %%
sc.settings.verbosity = 3
sc.settings.set_figure_params(dpi=80)

# %% [markdown]
# ## 1.3 Files and parameters

# %%
input_file = '../../../../DataDir/ExternalData/SingleCellData/Wang_ITrimester_adataMetacells.h5ad'

# %% [markdown]
# ## 1.4 Start computations

# %%
print(datetime.now())
# Out:
# 2026-03-20 13:59:28.366783

# %% [markdown]
# ----

# %% [markdown]
# # 2. Data Load

# %% [markdown]
# ## 2.1 Read adata metacells file

# %%
adata = sc.read(input_file)
adata
# Out:
# AnnData object with n_obs × n_vars = 308 × 20266
#     obs: 'cell_label', 'cell_label_purity', 'agg_sample_id', 'Aggregated_brain_region', 'Auth_Group'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'Aggregated_brain_region_colors', 'agg_sample_id_colors', 'cell_label_colors', 'hvg', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts', 'lognorm', 'raw'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(adata, color=['cell_label'], s=150)
# Out:
# /usr/local/lib/python3.8/dist-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# # 3. Exploration of hormonal receptor gene signature expression

# %%
signatures = '../../../../DataDir/ExternalData/Receptors/EndocrineKeyGenes.txt'
sig = pd.read_csv(signatures, sep="\t", keep_default_na=False)  
genes = sig["GeneName"].values.tolist()

# %%
fn.CustomUmap(adata, genes, embedding="X_umap", s=150)
# Out:
# Missing: {'CYP19A1', 'DIO3'}

# %%
adata.obs
# Out:
#                cell_label  cell_label_purity   agg_sample_id
# SEACell-214           ExN           0.755906  HDBR-14831-CTX  \
# SEACell-284    RadialGlia           0.934884  HDBR-14831-CTX
# SEACell-279           ExN           1.000000  HDBR-14831-CTX
# SEACell-35     RadialGlia           0.972678  HDBR-14831-CTX
# SEACell-37            OPC           1.000000  HDBR-14831-CTX
# ...                   ...                ...             ...
# SEACell-69     RadialGlia           0.631579   HDBR-15020-FB
# SEACell-167     Astrocyte           0.484848   HDBR-15020-FB
# SEACell-65       IPC-Glia           0.708333   HDBR-15020-FB
# SEACell-191  CajalRetzius           0.692308   HDBR-15020-FB
# SEACell-116           ExN           0.914286   HDBR-15020-FB
#
#             Aggregated_brain_region       Auth_Group
# SEACell-214               Neocortex  First_trimester
# SEACell-284               Neocortex  First_trimester
# SEACell-279               Neocortex  First_trimester
# SEACell-35                Neocortex  First_trimester
# SEACell-37                Neocortex  First_trimester
# ...                             ...              ...
# SEACell-69                Forebrain  First_trimester
# SEACell-167               Forebrain  First_trimester
# SEACell-65                Forebrain  First_trimester
# SEACell-191               Forebrain  First_trimester
# SEACell-116               Forebrain  First_trimester
#
# [308 rows x 5 columns]

# %%
outdir = "../../../../FigPaper/"

os.makedirs(outdir, exist_ok=True)

sc.settings.figdir = outdir

gene_dict = sig.groupby("Signature")["GeneName"].apply(list).to_dict()


gene_dict_filtered = {
    sig_name: [g for g in genes if g in adata.var_names]
    for sig_name, genes in gene_dict.items()
}

gene_dict_filtered = {k: v for k, v in gene_dict_filtered.items() if v}

if gene_dict_filtered:
    sc.pl.dotplot(
        adata,
        gene_dict_filtered,
        groupby='cell_label',
        save="dotplot_WangI.png"
    )
else:
    print("None of the specified genes are found.")
# Out:
# /usr/local/lib/python3.8/dist-packages/scanpy/plotting/_dotplot.py:749: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)
# WARNING: saving figure to file ../../../../FigPaper/dotplot_dotplot_WangI.png

# %% [markdown]
# # 4 Save in other formats

# %%
print(datetime.now())
# Out:
# 2026-03-20 13:59:33.487924

# %%
nb_fname = ipynbname.name()
nb_fname
# Out:
# 'SEACellsWang-GeneExploration_FirstTrimester'

# %%
# %%bash -s "$nb_fname"
# jupyter nbconvert "$1".ipynb --to="python"
# jupyter nbconvert "$1".ipynb --to="html"
# Out:
# [NbConvertApp] Converting notebook SEACellsWang-GeneExploration_FirstTrimester.ipynb to python
# [NbConvertApp] Writing 2718 bytes to SEACellsWang-GeneExploration_FirstTrimester.py
# [NbConvertApp] Converting notebook SEACellsWang-GeneExploration_FirstTrimester.ipynb to html
# [NbConvertApp] Writing 4305378 bytes to SEACellsWang-GeneExploration_FirstTrimester.html
